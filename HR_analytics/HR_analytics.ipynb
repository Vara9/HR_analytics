# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("HR-Employee-Attrition.csv")

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(df.mean(),inplace =True)
# Out:
# C:\Users\saiva\AppData\Local\Temp\ipykernel_13640\1109609052.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean(),inplace =True)

# %%
from scipy import stats

z_scores = np.abs(stats.zscore(df['DistanceFromHome']))
df_no_outliers = df[(z_scores <3)]

# %%
df_no_outliers
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_encoding = pd.get_dummies(df, columns=['Attrition'])

# %%
df_encoding
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
df['TotalWorkingYears']= df['YearsAtCompany'] + df[ 'YearsInCurrentRole']
total= df['TotalWorkingYears']
total.head(5)
# Out:
# 0    10
# 1    17
# 2     0
# 3    15
# 4     4
# Name: TotalWorkingYears, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.Gender
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3       Female
# 4         Male
#          ...
# 1465      Male
# 1466      Male
# 1467      Male
# 1468      Male
# 1469      Male
# Name: Gender, Length: 1470, dtype: object

# %%
numerical_val = df.select_dtypes(include =['number'])

# %%
corr_matrix = numerical_val.corr()

# %%
plt.figure(figsize = (10,8))
sns.heatmap(corr_matrix,annot = True,cmap='coolwarm',linewidths =.5)
plt.title = ('correlation matrix')
plt.show()

# %%
plt.hist(df['Department'],bins=20)
plt.xlabel('BusinessTravel')
plt.ylabel('BusinessTravel')
plt.show()

# %%
df.EmployeeCount.count()
# Out:
# 1470

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
dpt = df.groupby('Department')['EmployeeNumber'].count().reset_index()
dpt.columns = ['Department','EmployeeCount']

print(dpt)
# Out:
#                Department  EmployeeCount
# 0         Human Resources             63
# 1  Research & Development            961
# 2                   Sales            446

# %%
title='employee_count_per_department'


plt.hist(df['Department'],bins=20)
plt.xlabel('EmployeeCount')
plt.ylabel('EmployeeCOunt')

plt.show()

# %%
df['TotalWorkingYears'] =df['YearsAtCompany'] + df['YearsSinceLastPromotion']
df['TotalWorkingYears']
# Out:
# 0        6
# 1       11
# 2        0
# 3       11
# 4        4
#         ..
# 1465     5
# 1466     8
# 1467     6
# 1468     9
# 1469     5
# Name: TotalWorkingYears, Length: 1470, dtype: int64

# %%
df.Age.unique()
bins = [18,30,40,50,60]
labels =['18-30','31-40','41-50','51-60']
df['age_grp'] = pd.cut(df['Age'],bins=bins,labels=labels)

# %%
df['age_grp']
# Out:
# 0       41-50
# 1       41-50
# 2       31-40
# 3       31-40
# 4       18-30
#         ...
# 1465    31-40
# 1466    31-40
# 1467    18-30
# 1468    41-50
# 1469    31-40
# Name: age_grp, Length: 1470, dtype: category
# Categories (4, object): ['18-30' < '31-40' < '41-50' < '51-60']

# %%
age_Grp_count = df['age_grp'].value_counts().reset_index()
age_Grp_count.columns = ['Age group','count']
plt.bar (age_Grp_count['Age group'], age_Grp_count['count'])
plt.xlabel('Age group')
plt.ylabel('count')
plt.show()

# %%
df.OverTime
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467    Yes
# 1468     No
# 1469     No
# Name: OverTime, Length: 1470, dtype: object

# %%
df.Education.unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
df['TotalYearsInCurrRole'] =df['YearsAtCompany'] + df['YearsInCurrentRole']
df['TotalYearsInCurrRole']
# Out:
# 0       10
# 1       17
# 2        0
# 3       15
# 4        4
#         ..
# 1465     7
# 1466    14
# 1467     8
# 1468    15
# 1469     7
# Name: TotalYearsInCurrRole, Length: 1470, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'age_grp', 'TotalYearsInCurrRole'],
#       dtype='object')

# %%
df_encoding = pd.get_dummies(df, columns=['Attrition'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

features =['Age', 'Education','JobSatisfaction','TotalWorkingYears','YearsAtCompany','PerformanceRating']
X= df[features]
y=df['Attrition']

# %%
X.shape
# Out:
# (1470, 6)

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (1176, 6)

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

print(f'Accuracy Score is: {accuracy}')
# Out:
# Accuracy Score is: 0.8197278911564626

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn .metrics import mean_squared_error,r2_score
from sklearn.metrics import accuracy_score

features =['Age', 'Education','JobSatisfaction','TotalWorkingYears','YearsAtCompany','MonthlyIncome', 'MonthlyRate']
X= df[features]
y=df['PerformanceRating']

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2)

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
print(mse)
print(r2)
# Out:
# 0.1564625850340136
# -0.18548387096774177

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

feature = ['Age','JobSatisfaction','WorkLifeBalance']
X= df[feature]
y=df['Attrition']

X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.2)
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score (y_test,y_pred)
class_rep= classification_report(y_test,y_pred)
conf_mat = confusion_matrix (y_test,y_pred)


plt.figure(figsize=(8,5))
sns.heatmap(conf_mat,annot= True,fmt= 'd',cmap='Blues',xticklabels=['stayed','left'],yticklabels=['stayed','left'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# C:\Users\saiva\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiva\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\saiva\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - In our employee churn analysis , we've uncovered valuable insights into why employees leave our organization. Through data driven exploration, we've identified high risk groups, key factors contribution to attrition , and potential areas for improvement. These insights are instrumental in shaping our retention strategies.
#
# - By understanding the root cause and patterns behind employee turnover , we can proactively address issues such as job satisfaction, career development, and work-life balance. Our goal is to create a more engaging and supportive workplace , ultimately reducting attrition and retaining top talent.
#
#
# - NEXT STEP:
#  - Implement the identified retention strategies .
#  - Monitor attrition rates regularly to assess the impact of    the strategies.
#  - Maintain open communication channels for employee          feedback and concerns.
#
# - CONCLUSION:
#     - This analysis serves as a starting point for addressing  employee churn. It highlighs the importance of proactive retention efforts amd data-driven decision-making to create a more stable and satisfied workforce.
